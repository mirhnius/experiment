# %%
from nilearn.decomposition import CanICA

# %%
# func_filenames = ["/data/origami/niusha/out/out_2/vol0220.nii.gz",
# "/data/origami/niusha/out/out_2/vol0107.nii.gz"]
func_filenames = "/data/origami/niusha/out/DBM_data.nii"
canica = CanICA(n_components=30,
                memory="nilearn_cache", memory_level=2,
                verbose=10,
                mask_strategy='whole-brain-template',
                random_state=0)
canica.fit(func_filenames)
# Out:
# [MultiNiftiMasker.fit] Loading data from [/data/origami/niusha/out/DBM_data.nii].
# [{self.__class__.__name__}.fit] Computing mask
# Template whole-brain mask computation
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/joblib/memory.py:632: UserWarning: Cannot inspect object functools.partial(<function compute_multi_brain_mask at 0x7f0816dba160>, mask_type='whole-brain'), ignore list will not work.
#   return hashing.hash(filter_args(self.func, self.ignore, args, kwargs),
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/nilearn/maskers/multi_nifti_masker.py:258: JobLibCollisionWarning: Cannot detect name collisions for function 'unknown'
#   self.mask_img_ = self._cache(
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/joblib/memory.py:810: UserWarning: Cannot inspect object functools.partial(<function compute_multi_brain_mask at 0x7f0816dba160>, mask_type='whole-brain'), ignore list will not work.
# ...

# %%
canica_components_img = canica.components_img_
# components_img is a Nifti Image object, and can be saved to a file with
# the following line:
canica_components_img.to_filename('ICAs_original.nii.gz')

# %%
from nilearn.plotting import plot_prob_atlas

# Plot all ICA components together
plot_prob_atlas(canica_components_img, title='All ICA components')

# %%
from nilearn.image import iter_img
from nilearn.plotting import plot_stat_map, show

for i, cur_img in enumerate(iter_img(canica_components_img)):
    plot_stat_map(cur_img, display_mode="z", title="IC %d" % i,
                  cut_coords=1, colorbar=False)
# Out:
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/nilearn/plotting/displays/_slicers.py:144: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   figure = plt.figure(figure, figsize=figsize,

# %%
import nibabel as nib
img = nib.load("/data/origami/niusha/out/DBM_data.nii")

# %%
data = img.get_fdata()
ICs = canica_components_img.get_fdata()

# %%
img.shape
# Out:
# (101, 119, 97, 349)

# %%
canica_components_img.shape
# Out:
# (101, 119, 97, 30)

# %%
import numpy as np
mask = np.multiply(data[...,348],ICs[...,29])
mask.shape
# Out:
# (101, 119, 97)

# %%
msk_mean = np.mean(np.ravel(mask))
msk_mean
# Out:
# -7.829043961482099e-07

# %%
from nilearn.image import load_img, math_img
mask = math_img('img > 3', img=canica_components_img)

# %%
type(mask)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
np.nanmin(np.ravel(data[...,348]))
# Out:
# -5.151334504099293e+37

# %%
from nilearn.image import iter_img
from nilearn.plotting import plot_stat_map, show

for i, cur_img in enumerate(iter_img(mask)):
    plot_stat_map(cur_img, display_mode="z", title="IC %d" % i)
# Out:
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/nilearn/plotting/displays/_slicers.py:382: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))
# /data/origami/niusha/miniconda3/lib/python3.9/site-packages/nilearn/plotting/displays/_slicers.py:144: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   figure = plt.figure(figure, figsize=figsize,

# %%
from nilearn.image import load_img, math_img
tstat_img = load_img(...)
mask = math_img('img > 3', img=t_img)
mask.to_filename(...)
For thresholding, try the following:

sample_fc_networks = [image.threshold_img(entry, 3) for entry in sample_fc_network_files]
